# %%
import tight_loops

# %%
m = tight_loops.Map()

# %%
tight_loops.contour_tif_box("B5.TIF", "OUTPUT/new_contours.shp", interval=300)
# Out:
# .\whitebox_tools.exe --run="ContoursFromRaster" --input='c:\Users\18653\Documents\tight_loops\docs\examples\B5.TIF' --output='c:\Users\18653\Documents\tight_loops\docs\examples\OUTPUT\new_contours.shp' --interval=300 --base=0 --smooth=9 --tolerance=10 -v --compress_rasters=False
#
# *********************************
# * Welcome to ContoursFromRaster *
# * Powered by WhiteboxTools      *
# * www.whiteboxgeo.com           *
# *********************************
# Reading data...
# Reclassifying surface: 0%
# Reclassifying surface: 1%
# Reclassifying surface: 2%
# Reclassifying surface: 3%
# Reclassifying surface: 4%
# Reclassifying surface: 5%
# Reclassifying surface: 6%
# Reclassifying surface: 7%
# Reclassifying surface: 8%
# Reclassifying surface: 9%
# Reclassifying surface: 10%
# Reclassifying surface: 11%
# Reclassifying surface: 12%
# Reclassifying surface: 13%
# Reclassifying surface: 14%
# Reclassifying surface: 15%
# Reclassifying surface: 16%
# Reclassifying surface: 17%
# ...

# %%
m
# Out:
# Map(center=[0, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text'…

# %%
import geopandas as gpd

# %%
gdf = gpd.read_file("C:/Users/18653/Documents/tight_loops/docs/examples/OUTPUT/output_contours.shp")

# %%
print(gdf.crs.to_epsg())

# %%
new_contour = gdf.to_crs(epsg=4326, inplace=False).__geo_interface__

# %%
m.add_geojson(new_contour)

# %%
m.add_shp("OUTPUT/new_contours.shp")

# %%
m.layers

# %%
m.add_geojson("countries.geojson")

# %%
m

# %%
import leafmap

# %%
m = leafmap.Map()

# %%
m

# %%
m.add_shp("OUTPUT/output_contours.shp")
